# %% [markdown]
# <a href="https://colab.research.google.com/github/Tayyab666-star/Pak-Angels-Hackathon/blob/main/Hackathon_pak_Angels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium

# Create Map centered on a sample location
m = folium.Map(location=[37.7749, -122.4194], zoom_start=12)

# Add a sample marker
folium.Marker([37.7749, -122.4194], tooltip="Traffic Hotspot").add_to(m)

# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
import folium

# Create a Map centered on Pakistan (Lahore as default)
m = folium.Map(location=[31.5204, 74.3587], zoom_start=6)

# List of major cities in Pakistan with simulated traffic congestion
traffic_points = [
    {"city": "Lahore", "lat": 31.5204, "lon": 74.3587, "status": "High Congestion"},
    {"city": "Karachi", "lat": 24.8607, "lon": 67.0011, "status": "Medium Congestion"},
    {"city": "Islamabad", "lat": 33.6844, "lon": 73.0479, "status": "Low Congestion"},
    {"city": "Peshawar", "lat": 34.0151, "lon": 71.5249, "status": "Medium Congestion"},
]

# Add traffic markers with different colors based on congestion level
for point in traffic_points:
    color = "red" if point["status"] == "High Congestion" else "orange" if point["status"] == "Medium Congestion" else "green"

    folium.Marker(
        [point["lat"], point["lon"]],
        tooltip=f"{point['city']} - {point['status']}",
        icon=folium.Icon(color=color)
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # New Section

# %%
import requests

city = "Lahore, Pakistan"
url = f"https://nominatim.openstreetmap.org/search?format=json&q={city}"

response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
data = response.json()

if data:
    lat, lon = float(data[0]["lat"]), float(data[0]["lon"])
    print(f"Coordinates of {city}: Latitude = {lat}, Longitude = {lon}")
else:
    print("Location not found!")
# Out:
# Coordinates of Lahore, Pakistan: Latitude = 31.5656822, Longitude = 74.3141829

# %%
pip install folium requests
import folium
import requests

# Function to get coordinates from OpenStreetMap (OSM) Nominatim API
def get_location_coordinates(city_name):
    url = f"https://nominatim.openstreetmap.org/search?format=json&q={city_name},Pakistan"

    try:
        response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}, timeout=10)
        response.raise_for_status()  # Raise an error if request fails
        data = response.json()

        if data and len(data) > 0:
            lat, lon = float(data[0]["lat"]), float(data[0]["lon"])
            return lat, lon
        else:
            print(f"❌ No location found for {city_name}")
            return None, None

    except requests.exceptions.RequestException as e:
        print(f"⚠️ Error fetching data for {city_name}: {e}")
        return None, None

# ✅ Take user input for the desired city
user_city = input("Enter a city in Pakistan: ")

# ✅ Get coordinates for the user input city
lat, lon = get_location_coordinates(user_city)

if lat and lon:
    # ✅ Create a map centered on the user's desired location
    m = folium.Map(location=[lat, lon], zoom_start=12)

    # ✅ Add a marker for the entered city
    folium.Marker(
        [lat, lon],
        tooltip=f"{user_city} (User Input Location)",
        icon=folium.Icon(color="blue")
    ).add_to(m)

    # ✅ Display the map
    m
else:
    print("⚠️ Could not fetch location. Try another city.")
# Out:
#   File "<ipython-input-11-521743d77f60>", line 1
#     pip install folium requests
#         ^
# SyntaxError: invalid syntax

# %%
import folium

# Create a Map centered on Pakistan (Lahore as default)
m = folium.Map(location=[31.5204, 74.3587], zoom_start=6)

# List of major cities in Pakistan with simulated traffic congestion
traffic_points = [
    {"city": "Lahore", "lat": 31.5204, "lon": 74.3587, "status": "High Congestion"},
    {"city": "Karachi", "lat": 24.8607, "lon": 67.0011, "status": "Medium Congestion"},
    {"city": "Islamabad", "lat": 33.6844, "lon": 73.0479, "status": "Low Congestion"},
    {"city": "Peshawar", "lat": 34.0151, "lon": 71.5249, "status": "Medium Congestion"},
    {"city": "Faisalabad", "lat": 31.4504, "lon": 73.1350, "status": "High Congestion"},  # Added Faisalabad
]

# Add traffic markers with different colors based on congestion level
for point in traffic_points:
    color = "red" if point["status"] == "High Congestion" else "orange" if point["status"] == "Medium Congestion" else "green"

    folium.Marker(
        [point["lat"], point["lon"]],
        tooltip=f"{point['city']} - {point['status']}",
        icon=folium.Icon(color=color)
    ).add_to(m)

# Display the map
m

# %%
# !pip install requests folium
import requests
import json

def get_location(city_name):
    base_url = "https://nominatim.openstreetmap.org/search"
    params = {
        "q": city_name + ", Pakistan",  # Ensure location is in Pakistan
        "format": "json",
        "limit": 1  # Get only the first result
    }

    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json()
        if data:
            return float(data[0]["lat"]), float(data[0]["lon"])  # Return latitude & longitude
        else:
            print(f"No location found for {city_name}")
            return None
    else:
        print("Error fetching data:", response.status_code)
        return None
import folium

# User enters city name
city = input("Enter a city in Pakistan: ")
location = get_location(city)

if location:
    lat, lon = location
    print(f"Coordinates of {city}: {lat}, {lon}")

    # Create a map centered at the entered location
    map_obj = folium.Map(location=[lat, lon], zoom_start=12)

    # Add a marker for the city
    folium.Marker(
        [lat, lon],
        tooltip=f"Location: {city}",
        popup=f"{city} - Lat: {lat}, Lon: {lon}"
    ).add_to(map_obj)

    # Display the map
    map_obj
# Out:
# ...
# Enter a city in Pakistan: Lahore
# Error fetching data: 403

# %%
import requests

def get_location(city_name):
    base_url = "https://nominatim.openstreetmap.org/search"
    params = {
        "q": city_name + ", Pakistan",
        "format": "json",
        "limit": 1
    }

    # Add User-Agent to avoid 403 error
    headers = {
        "User-Agent": "YourAppName/1.0 (your_email@example.com)"
    }

    response = requests.get(base_url, params=params, headers=headers)

    if response.status_code == 200:
        data = response.json()
        if data:
            return float(data[0]["lat"]), float(data[0]["lon"])
        else:
            print(f"No location found for {city_name}")
            return None
    else:
        print(f"Error fetching data: {response.status_code}")
        return None

# %%
# Step 1: Install required libraries
# !pip install openai requests

# Step 2: Import dependencies
import openai
import requests

# Step 3: Set up API keys (Replace with actual API keys)
GROQ_API_KEY = "your_groq_api_key_here"

# Step 4: Configure OpenAI-compatible client for Groq
client = openai.OpenAI(
    api_key=GROQ_API_KEY,
    base_url="https://api.groq.com/openai/v1"
)

# Step 5: Function to get coordinates from Nominatim API
def get_coordinates(location):
    base_url = "https://nominatim.openstreetmap.org/search"
    params = {
        "q": location + ", Pakistan",
        "format": "json",
        "limit": 1
    }
    headers = {"User-Agent": "YourAppName/1.0 (your_email@example.com)"}

    response = requests.get(base_url, params=params, headers=headers)

    if response.status_code == 200:
        data = response.json()
        if data:
            return float(data[0]["lat"]), float(data[0]["lon"])
        else:
            return None
    else:
        print(f"Error fetching data: {response.status_code}")
        return None

# Step 6: Function to get route from OpenStreetMap API
def get_route(start, destination):
    start_coords = get_coordinates(start)
    destination_coords = get_coordinates(destination)

    if not start_coords or not destination_coords:
        return "Invalid locations. Please try again."

    base_url = "https://router.project-osrm.org/route/v1/driving/"
    route_url = f"{base_url}{start_coords[1]},{start_coords[0]};{destination_coords[1]},{destination_coords[0]}?overview=full&geometries=geojson"

    response = requests.get(route_url)

    if response.status_code == 200:
        data = response.json()
        if "routes" in data and data["routes"]:
            return "Optimized route found. Map is being generated."
        else:
            return "No route found."
    else:
        return f"Error fetching route data: {response.status_code}"

# Step 7: Chatbot function using Groq API
def chat_with_groq(prompt, model="llama3-8b", max_tokens=500):
    try:
        response = client.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": prompt}],
            max_tokens=max_tokens
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Error: {str(e)}"

# Step 8: Interactive chatbot loop
while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye!")
        break

    # Check for route request keywords
    if "route" in user_input.lower():
        print("\nChatbot: Please enter starting location:")
        start = input("Start: ")

        print("\nChatbot: Please enter destination:")
        destination = input("Destination: ")

        # Get optimized route
        optimized_route = get_route(start, destination)
        print(f"\nChatbot: {optimized_route}\n")

    else:
        # Chat with Groq API
        response = chat_with_groq(user_input)
        print(f"Chatbot: {response}")
# Out:
# ...
# You: Lahore
# Chatbot: Error: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-a0a7deb77cfa> in <cell line: 0>()
#      73 # Step 8: Interactive chatbot loop
#      74 while True:
# ---> 75     user_input = input("You: ")
#      76
#      77     if user_input.lower() in ["exit", "quit", "bye"]:
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
# Step 1: Install required libraries
# !pip install openai requests

# Step 2: Import dependencies
import openai
import requests

# Step 3: Set up Groq API Key
GROQ_API_KEY = "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"

# Step 4: Configure OpenAI-compatible client for Groq
client = openai.OpenAI(
    api_key=GROQ_API_KEY,
    base_url="https://api.groq.com/openai/v1"
)

# Step 5: Function to get coordinates from Nominatim API
def get_coordinates(location):
    base_url = "https://nominatim.openstreetmap.org/search"
    params = {
        "q": location + ", Pakistan",
        "format": "json",
        "limit": 1
    }
    headers = {"User-Agent": "YourAppName/1.0 (your_email@example.com)"}

    response = requests.get(base_url, params=params, headers=headers)

    if response.status_code == 200:
        data = response.json()
        if data:
            return float(data[0]["lat"]), float(data[0]["lon"])
        else:
            return None
    else:
        print(f"Error fetching data: {response.status_code}")
        return None

# Step 6: Function to get route from OpenStreetMap API
def get_route(start, destination):
    start_coords = get_coordinates(start)
    destination_coords = get_coordinates(destination)

    if not start_coords or not destination_coords:
        return "Invalid locations. Please try again."

    base_url = "https://router.project-osrm.org/route/v1/driving/"
    route_url = f"{base_url}{start_coords[1]},{start_coords[0]};{destination_coords[1]},{destination_coords[0]}?overview=full&geometries=geojson"

    response = requests.get(route_url)

    if response.status_code == 200:
        data = response.json()
        if "routes" in data and data["routes"]:
            return "Optimized route found. Map is being generated."
        else:
            return "No route found."
    else:
        return f"Error fetching route data: {response.status_code}"

# Step 7: Chatbot function using Groq API
def chat_with_groq(prompt, model="llama3-8b", max_tokens=500):
    try:
        response = client.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": prompt}],
            max_tokens=max_tokens
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Error: {str(e)}"

# Step 8: Interactive chatbot loop
while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye!")
        break

    # Check for route request keywords
    if "route" in user_input.lower():
        print("\nChatbot: Please enter starting location:")
        start = input("Start: ")

        print("\nChatbot: Please enter destination:")
        destination = input("Destination: ")

        # Get optimized route
        optimized_route = get_route(start, destination)
        print(f"\nChatbot: {optimized_route}\n")

    else:
        # Chat with Groq API
        response = chat_with_groq(user_input)
        print(f"Chatbot: {response}")

# %%
# Install dependencies
# !pip install requests

# Import required libraries
import requests

# Function to get route between two locations
def get_route(start, destination):
    start_lat, start_lon = get_location_coordinates(start)
    dest_lat, dest_lon = get_location_coordinates(destination)

    if not start_lat or not dest_lat:
        return "Invalid locations."

    route_url = f"https://router.project-osrm.org/route/v1/driving/{start_lon},{start_lat};{dest_lon},{dest_lat}?overview=full&geometries=geojson"
    response = requests.get(route_url)

    if response.status_code == 200:
        route_data = response.json()
        return route_data["routes"][0]["geometry"]["coordinates"]
    else:
        return "Error fetching route."

# Test route
route = get_route("Lahore, Pakistan", "Islamabad, Pakistan")
print("Route Coordinates:", route)

# %%
# Install dependencies
# !pip install openai

# Import required libraries
import openai

# Set up Groq API key
GROQ_API_KEY = "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"

# Initialize OpenAI-compatible client for Groq
client = openai.OpenAI(
    api_key=GROQ_API_KEY,
    base_url="https://api.groq.com/openai/v1"
)

# Function to generate responses
def chat_with_groq(prompt, model="llama3-8b", max_tokens=300):
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        max_tokens=max_tokens
    )
    return response.choices[0].message.content

# Test chatbot
user_query = "What is the capital of Pakistan?"
response = chat_with_groq(user_query)
print("Chatbot:", response)

# %%
# Install dependencies
# !pip install requests

# Import required libraries
import requests

# Function to get route between two locations
def get_route(start, destination):
    start_lat, start_lon = get_location_coordinates(start)
    dest_lat, dest_lon = get_location_coordinates(destination)

    if not start_lat or not dest_lat:
        return "Invalid locations."

    route_url = f"https://router.project-osrm.org/route/v1/driving/{start_lon},{start_lat};{dest_lon},{dest_lat}?overview=full&geometries=geojson"
    response = requests.get(route_url)

    if response.status_code == 200:
        route_data = response.json()
        return route_data["routes"][0]["geometry"]["coordinates"]
    else:
        return "Error fetching route."

# Test route
route = get_route("Lahore, Pakistan", "Islamabad, Pakistan")
print("Route Coordinates:", route)

# %% [markdown]
# # New Section

# %%
# ✅ Step 1: Install required dependencies
# !pip install openai requests folium

# ✅ Step 2: Import necessary libraries
import openai
import requests
import folium
from google.colab import files

# ✅ Step 3: Set up API Keys (Replace with your Groq API Key)
GROQ_API_KEY = "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"

# ✅ Step 4: Initialize OpenAI-compatible client for Groq
client = openai.OpenAI(
    api_key=GROQ_API_KEY,
    base_url="https://api.groq.com/openai/v1"
)

# ✅ Step 5: Function to fetch coordinates from OSM Nominatim
def get_location_coordinates(location_name):
    url = f"https://nominatim.openstreetmap.org/search?q={location_name}&format=json"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        if len(data) > 0:
            return float(data[0]["lat"]), float(data[0]["lon"])
    return None

# ✅ Step 6: Function to get optimized route using OSM Routing API
def get_route(start, destination):
    start_coords = get_location_coordinates(start)
    dest_coords = get_location_coordinates(destination)

    if not start_coords or not dest_coords:
        return "Error: Invalid start or destination location."

    # Create map centered at start location
    m = folium.Map(location=start_coords, zoom_start=12)

    # Add markers
    folium.Marker(start_coords, tooltip="Start Location", icon=folium.Icon(color="green")).add_to(m)
    folium.Marker(dest_coords, tooltip="Destination", icon=folium.Icon(color="red")).add_to(m)

    # Save and download map
    m.save("route_map.html")
    files.download("route_map.html")

    return "Route map generated! Download and open the HTML file to view."

# ✅ Step 7: Chatbot function using Groq API
def chat_with_groq(prompt, model="llama3-8b", max_tokens=500):
    try:
        response = client.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": prompt}],
            max_tokens=max_tokens
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"Error: {str(e)}"

# ✅ Step 8: Interactive chatbot loop
while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye!")
        break

    # Route request detection
    if "route" in user_input.lower():
        print("\nChatbot: Enter starting location:")
        start = input("Start: ")

        print("\nChatbot: Enter destination:")
        destination = input("Destination: ")

        # Get optimized route and show map
        result = get_route(start, destination)
        print(f"\nChatbot: {result}\n")

    else:
        # Chatbot conversation using Groq API
        response = chat_with_groq(user_input)
        print(f"Chatbot: {response}")

# %%
# Step 1: Install required libraries
# !pip install transformers torch requests

# Step 2: Import dependencies
import requests
from transformers import AutoModelForCausalLM, AutoTokenizer

# Step 3: Set up API Key (Replace with your actual Groq API Key)
GROQ_API_KEY = "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"

# Step 4: Load a free LLM from Hugging Face (Mistral-7B)
model_name = "mistralai/Mistral-7B-v0.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Step 5: Function to chat with the free Hugging Face LLM
def chat_with_hf(prompt):
    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=500)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response

# Step 6: Function to chat with Groq API
def chat_with_groq(prompt, model="gemma-7b-it", max_tokens=500):
    url = "https://api.groq.com/openai/v1/chat/completions"
    headers = {"Authorization": f"Bearer {GROQ_API_KEY}", "Content-Type": "application/json"}
    payload = {"model": model, "messages": [{"role": "user", "content": prompt}], "max_tokens": max_tokens}

    try:
        response = requests.post(url, headers=headers, json=payload)
        response.raise_for_status()  # Raise an error for non-200 responses
        return response.json()["choices"][0]["message"]["content"]
    except requests.exceptions.RequestException as e:
        return f"Error: {str(e)}"

# Step 7: Interactive chatbot loop
while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye!")
        break

    # Use Hugging Face for offline responses, Groq API for online responses
    hf_response = chat_with_hf(user_input)
    groq_response = chat_with_groq(user_input)

    # Print both responses
    print(f"\n🤖 Hugging Face Chatbot: {hf_response}")
    print(f"\n🚀 Groq API Chatbot: {groq_response}\n")

# %%
import requests
from transformers import AutoModelForCausalLM, AutoTokenizer
import time

# ✅ Use your correct Groq API Key
GROQ_API_KEY = "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"

# ✅ Load Free LLM from Hugging Face
model_name = "mistralai/Mistral-7B-v0.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# ✅ Function to chat with Hugging Face LLM (Offline)
def chat_with_hf(prompt):
    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=500)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response

# ✅ Function to chat with Groq API (Online)
def chat_with_groq(prompt, model="mixtral-8x7b", max_tokens=500):
    url = "https://api.groq.com/openai/v1/chat/completions"
    headers = {"Authorization": f"Bearer {GROQ_API_KEY}", "Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "max_tokens": max_tokens,
        "temperature": 0.7
    }

    try:
        response = requests.post(url, headers=headers, json=payload)
        response.raise_for_status()
        return response.json()["choices"][0]["message"]["content"]
    except requests.exceptions.RequestException as e:
        return f"Error: {str(e)}"

# ✅ Interactive Chatbot Loop
while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye!")
        break

    # ✅ Add a delay to prevent rate limits
    time.sleep(1)

    # ✅ Get responses from Hugging Face (Offline) & Groq API (Online)
    hf_response = chat_with_hf(user_input)
    groq_response = chat_with_groq(user_input)

    print(f"\n🤖 Hugging Face Chatbot: {hf_response}")
    print(f"\n🚀 Groq API Chatbot: {groq_response}\n")
